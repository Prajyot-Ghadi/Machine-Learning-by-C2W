# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('IPL_Matches_tail_300.csv')
df.head()
# Out:
#          date  season     city                      venue  \
# 0  20-05-2022    2022   Mumbai  Brabourne Stadium, Mumbai
# 1  21-05-2022    2022   Mumbai   Wankhede Stadium, Mumbai
# 2  22-05-2022    2022   Mumbai   Wankhede Stadium, Mumbai
# 3  24-05-2022    2022  Kolkata      Eden Gardens, Kolkata
# 4  25-05-2022    2022  Kolkata      Eden Gardens, Kolkata
#
#                          team1                 team2           toss_winner  \
# 0          Chennai Super Kings      Rajasthan Royals   Chennai Super Kings
# 1               Delhi Capitals        Mumbai Indians        Mumbai Indians
# 2          Sunrisers Hyderabad          Punjab Kings   Sunrisers Hyderabad
# 3             Rajasthan Royals        Gujarat Titans        Gujarat Titans
# 4  Royal Challengers Bangalore  Lucknow Super Giants  Lucknow Super Giants
#
#   toss_decision  team1_runs  team1_wickets  ...  win_by_wickets  \
# 0           bat       150.0              6  ...               5
# 1         field       159.0              7  ...               5
# 2           bat       157.0              8  ...               5
# 3         field       188.0              6  ...               7
# 4         field       207.0              4  ...               0
#
#    player_of_match match_referee        umpire1        umpire2     tv_umpire  \
# 0         R Ashwin      M Nayyar    CB Gaffaney  NA Patwardhan      YC Barde
# 1        JJ Bumrah     J Srinath    Nitin Menon   Tapan Sharma    HAS Khalid
# 2    Harpreet Brar     J Srinath   AK Chaudhary  NA Patwardhan   CB Gaffaney
# 3        DA Miller      M Nayyar   BNJ Oxenford      VK Sharma      MA Gough
# 4       RM Patidar      M Nayyar  J Madanagopal       MA Gough  BNJ Oxenford
#
#      reserve_umpire overs_limit  \
# 0         PG Pathak          20
# 1  GR Sadashiv Iyer          20
# 2     Navdeep Singh          20
# 3     J Madanagopal          20
# 4         VK Sharma          20
#
#                                        team1_players  \
# 0  RD Gaikwad, DP Conway, MM Ali, N Jagadeesan, A...
# 1  PP Shaw, DA Warner, MR Marsh, RR Pant, SN Khan...
# 2  PK Garg, Abhishek Sharma, RA Tripathi, AK Mark...
# 3  YBK Jaiswal, JC Buttler, SV Samson, D Padikkal...
# 4  V Kohli, F du Plessis, RM Patidar, GJ Maxwell,...
#
#                                        team2_players
# 0  YBK Jaiswal, JC Buttler, SV Samson, D Padikkal...
# 1  Ishan Kishan, RG Sharma, D Brevis, Tilak Varma...
# 2  JM Bairstow, S Dhawan, M Shahrukh Khan, MA Aga...
# 3  WP Saha, Shubman Gill, MS Wade, HH Pandya, DA ...
# 4  Q de Kock, KL Rahul, M Vohra, DJ Hooda, MP Sto...
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (300, 25)

# %%
df.columns
# Out:
# Index(['date', 'season', 'city', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'team1_runs', 'team1_wickets', 'team2_runs',
#        'team2_wickets', 'winner', 'result_type', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'match_referee', 'umpire1',
#        'umpire2', 'tv_umpire', 'reserve_umpire', 'overs_limit',
#        'team1_players', 'team2_players'],
#       dtype='object')

# %%
df.tail().isnull().sum().sort_values(ascending=False)
# Out:
# team1_runs         1
# winner             1
# player_of_match    1
# team2_runs         1
# date               0
# team1              0
# season             0
# venue              0
# city               0
# toss_decision      0
# toss_winner        0
# team2              0
# team1_wickets      0
# team2_wickets      0
# result_type        0
# win_by_runs        0
# win_by_wickets     0
# match_referee      0
# umpire1            0
# umpire2            0
# tv_umpire          0
# reserve_umpire     0
# overs_limit        0
# team1_players      0
# team2_players      0
# dtype: int64

# %%
mean_df = df.copy()
mean_value = mean_df['team1_runs'].mean()
print('Mean : ', mean_value)
# Out:
# Mean :  188.13651877133105

# %%
mean_df['team1_runs'] = mean_df['team1_runs'].fillna(mean_value)
mean_df['team1_runs'].isnull().sum()
# Out:
# np.int64(0)

# %%
median_df = df.copy()
median_value = median_df['team2_runs'].median()
print('Median : ', median_value)
# Out:
# Median :  175.0

# %%
median_df['team2_runs'] = median_df['team2_runs'].fillna(median_value)
